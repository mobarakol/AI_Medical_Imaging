# %% [markdown]
# <a href="https://colab.research.google.com/github/mobarakol/AI_Medical_Imaging/blob/main/LIME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LIME
#
# Installation

# %%
# !pip install -q interpret lime
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 72.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 51.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.1/780.1 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 7.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# Download the dataset

# %%
# !git clone https://github.com/mobarakol/AI_Medical_Imaging.git
# %cd AI_Medical_Imaging
# Out:
# Cloning into 'AI_Medical_Imaging'...
# remote: Enumerating objects: 296, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 296 (delta 19), reused 13 (delta 13), pack-reused 265 (from 2)
# Receiving objects: 100% (296/296), 24.16 MiB | 20.82 MiB/s, done.
# Resolving deltas: 100% (135/135), done.
# /content/AI_Medical_Imaging

# %% [markdown]
# #Stroke Prediction Dataset
# Source: https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset<br>
#
# Attribute Information<br>
# 1) id: unique identifier<br>
# 2) gender: "Male", "Female" or "Other"<br>
# 3) age: age of the patient<br>
# 4) hypertension: 0 if the patient doesn't have hypertension, 1 if the patient has hypertension<br>
# 5) heart_disease: 0 if the patient doesn't have any heart diseases, 1 if the patient has a heart disease<br>
# 6) ever_married: "No" or "Yes"<br>
# 7) work_type: "children", "Govt_jov", "Never_worked", "Private" or "Self-employed"<br>
# 8) Residence_type: "Rural" or "Urban"<br>
# 9) avg_glucose_level: average glucose level in blood<br>
# 10) bmi: body mass index<br>
# 11) smoking_status: "formerly smoked", "never smoked", "smokes" or "Unknown"*<br>
# 12) stroke: 1 if the patient had a stroke or 0 if not

# %%
# %cd /content/AI_Medical_Imaging
import pandas as pd
path = '/content/AI_Medical_Imaging/data/healthcare-dataset-stroke-data.csv'
data = pd.read_csv(path)
print('Sample Size:', len(data))
data.head(5)
# Out:
# /content/AI_Medical_Imaging
# Sample Size: 5110
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# #Dataloader

# %%
import pandas as pd
# Makes sure we see all columns
pd.set_option('display.max_columns', None)
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler

class DataLoader():
    def __init__(self):
        self.data = None

    def load_dataset(self, path="data/healthcare-dataset-stroke-data.csv"):
        self.data = pd.read_csv(path)

    def preprocess_data(self):
        # One-hot encode all categorical columns
        categorical_cols = ["gender",
                            "ever_married",
                            "work_type",
                            "Residence_type",
                            "smoking_status"]
        encoded = pd.get_dummies(self.data[categorical_cols],
                               prefix=categorical_cols, dtype=int)

        # Update data with new columns
        self.data = pd.concat([encoded, self.data], axis=1)
        self.data.drop(categorical_cols, axis=1, inplace=True)

        # Impute missing values of BMI
        self.data.bmi = self.data.bmi.fillna(0)

        # Drop id as it is not relevant
        self.data.drop(["id"], axis=1, inplace=True)

        # Standardization
        # Usually we would standardize here and convert it back later
        # But for simplification we will not standardize / normalize the features

    def get_data_split(self):
        X = self.data.iloc[:,:-1]
        y = self.data.iloc[:,-1]
        return train_test_split(X, y, test_size=0.20, random_state=2021)

    def oversample(self, X_train, y_train):
        oversample = RandomOverSampler(sampling_strategy='minority')
        # Convert to numpy and oversample
        x_np = X_train.to_numpy()
        y_np = y_train.to_numpy()
        x_np, y_np = oversample.fit_resample(x_np, y_np)
        # Convert back to pandas
        x_over = pd.DataFrame(x_np, columns=X_train.columns)
        y_over = pd.Series(y_np, name=y_train.name)
        return x_over, y_over

# %%
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", None)

from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler


class DataLoader:
    def __init__(self):
        self.data = None
        self.target_col = "stroke"

    def load_dataset(self, path="data/healthcare-dataset-stroke-data.csv"):
        self.data = pd.read_csv(path)

    @staticmethod
    def _to_numeric_strict(df: pd.DataFrame) -> pd.DataFrame:
        """
        Convert any lingering non-numeric values to numeric.
        Specifically fixes values like 'True'/'False' (strings) that break LIME.
        """
        df = df.copy()

        # Normalize common boolean-like strings
        bool_map = {
            "true": 1, "false": 0,
            "True": 1, "False": 0,
            True: 1, False: 0,
        }

        for col in df.columns:
            if df[col].dtype == "object" or pd.api.types.is_bool_dtype(df[col]):
                df[col] = df[col].map(bool_map).where(df[col].isin(bool_map), df[col])

        # Coerce everything to numeric if possible
        for col in df.columns:
            if not pd.api.types.is_numeric_dtype(df[col]):
                df[col] = pd.to_numeric(df[col], errors="coerce")

        # Any new NaNs created by coercion get filled
        df = df.fillna(0)
        return df

    def preprocess_data(self):
        df = self.data.copy()

        # Drop id if present
        if "id" in df.columns:
            df = df.drop(columns=["id"])

        # Impute BMI missing values (dataset has NaNs)
        if "bmi" in df.columns:
            df["bmi"] = pd.to_numeric(df["bmi"], errors="coerce").fillna(0)

        # One-hot encode categorical columns (only those that exist)
        categorical_cols = ["gender", "ever_married", "work_type", "Residence_type", "smoking_status"]
        categorical_cols = [c for c in categorical_cols if c in df.columns]

        if categorical_cols:
            df = pd.get_dummies(df, columns=categorical_cols, dtype=np.int64)

        # Ensure target is numeric 0/1
        if self.target_col in df.columns:
            df[self.target_col] = pd.to_numeric(df[self.target_col], errors="coerce").fillna(0).astype(int)

        # Final: force all features numeric (this is what fixes your 'False' string issue)
        feature_cols = [c for c in df.columns if c != self.target_col]
        df[feature_cols] = self._to_numeric_strict(df[feature_cols])

        self.data = df

    def get_data_split(self):
        X = self.data.drop(columns=[self.target_col])
        y = self.data[self.target_col]

        return train_test_split(
            X, y,
            test_size=0.20,
            random_state=2021,
            stratify=y
        )

    def oversample(self, X_train, y_train):
        ros = RandomOverSampler(sampling_strategy="minority", random_state=2021)

        X_res, y_res = ros.fit_resample(X_train, y_train)

        # Keep types clean and numeric
        X_res = X_res.astype(np.float64)
        y_res = y_res.astype(int)

        return X_res, y_res

# %% [markdown]
# #LIME

# %%
# %cd /content/AI_Medical_Imaging

import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, accuracy_score

from interpret.blackbox import LimeTabular
from interpret import show
import warnings
warnings.filterwarnings("ignore")

# Load and preprocess
data_loader = DataLoader()
data_loader.load_dataset("data/healthcare-dataset-stroke-data.csv")
data_loader.preprocess_data()

X_train, X_test, y_train, y_test = data_loader.get_data_split()
X_train, y_train = data_loader.oversample(X_train, y_train)

print(X_train.shape)
print(X_test.shape)

# Fit model
rf = RandomForestClassifier(random_state=2021)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
print(f"F1 Score {f1_score(y_test, y_pred, average='macro')}")
print(f"Accuracy {accuracy_score(y_test, y_pred)}")

# ---- LIME (InterpretML) ----
# IMPORTANT: pass purely numeric float data into LimeTabular
X_train_np = X_train.to_numpy(dtype=np.float64, copy=False)
X_test_np = X_test.to_numpy(dtype=np.float64, copy=False)

lime = LimeTabular(
    model=rf.predict_proba,
    data=X_train_np,
    feature_names=list(X_train.columns),
    random_state=1
)

# Use iloc to take last 20 rows safely, then convert to numpy
X_last20 = X_test.iloc[-20:].to_numpy(dtype=np.float64, copy=False)
y_last20 = y_test.iloc[-20:].to_numpy()

lime_local = lime.explain_local(
    X_last20,
    y_last20,
    name="LIME"
)

show(lime_local)
# Out:
# /content/AI_Medical_Imaging
# (7778, 21)
# (1022, 21)
# F1 Score 0.5132174327220766
# Accuracy 0.9373776908023483
#         <script type="text/javascript" src="https://unpkg.com/@interpretml/interpret-inline@0.7.6/dist/interpret-inline.js"></script>
#
#     <div id="_interpret-viz-8bc59a34-2d06-4e79-8681-3d24d491d1a2"></div>
#     <script defer type="text/javascript">
#
#     (function universalLoad(root, callback) {
#       if(typeof exports === 'object' && typeof module === 'object') {
#         // CommonJS2
#         console.log("CommonJS2");
#         var interpretInline = require('interpret-inline');
#         callback(interpretInline);
#       } else if(typeof define === 'function' && define.amd) {
#         // AMD
#         console.log("AMD");
#         require(['interpret-inline'], function(interpretInline) {
#           callback(interpretInline);
#         });
#       } else if(typeof exports === 'object') {
#         // CommonJS
#         console.log("CommonJS");
# ...
